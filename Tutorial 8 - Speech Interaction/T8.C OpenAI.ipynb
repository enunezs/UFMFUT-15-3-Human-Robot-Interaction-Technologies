# %% [markdown]
# # 0. Setup

# %%
# !pip install openai

# %% [markdown]
# # Open AI

# %% [markdown]
# ## Open AI key

# %%
import openai

# Replace with your actual API key
# !OPENAI_API_KEY="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"
openai.api_key = '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'
# Out:
# 'OPENAI_API_KEY' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Base use

# %%
response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user",
     "content": "Do you like waffles?"}
  ],
  temperature=0.0,
  max_tokens=50
)

print(response.choices[0].message.content)
# Out:
# I'm an AI assistant, so I don't have personal preferences. But many people enjoy waffles!

# %% [markdown]
# Giving specific roles or instructions

# %%
response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are a helpful assistant but give brief answers as json code"
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "How do you create a helpful robot?"
        }
      ]
    }
  ],
  temperature=0.5,
  max_tokens=100
)

print(response.choices[0].message.content)
# Out:
# {
#   "response": "To create a helpful robot, you need to define its purpose clearly, program it with relevant skills and knowledge, and ensure it can effectively interact with humans through intuitive interfaces."
# }

# %% [markdown]
# Perform sentiment analysis

# %%
def analyze_sentiment(text):
    try:
        # Call the OpenAI API for sentiment analysis
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "user", "content": f"Analyze the sentiment of this text: '{text}'"}
            ],
            max_tokens=50
        )

        # Extract sentiment from the response
        sentiment = response.choices[0].message.content
        return sentiment

    except Exception as e:
        return f"Error: {str(e)}"

def main():
    # Sample texts for sentiment analysis
    sample_texts = [
        "I love this product! It's amazing.",
        "I'm really disappointed with the service.",
        "It's an okay experience, nothing special.",
        "What a wonderful day! I feel so happy.",
        "I'm not sure how I feel about this."
    ]

    # Analyze sentiment for each sample text
    for text in sample_texts:
        sentiment = analyze_sentiment(text)
        print(f"Text: {text}\nSentiment: {sentiment}\n")

if __name__ == "__main__":
    main()
# Out:
# Text: I love this product! It's amazing.
# Sentiment: Sentiment: Positive
#
# The text expresses a strong positive sentiment towards the product, with the use of words like "love" and "amazing".
#
# Text: I'm really disappointed with the service.
# Sentiment: The sentiment of this text is negative, specifically disappointment. The use of the word "disappointed" conveys a feeling of dissatisfaction or letdown towards the service received.
#
# Text: It's an okay experience, nothing special.
# Sentiment: The sentiment of this text is neutral. The speaker seems to be neither overly positive nor negative about their experience, describing it as "okay" and "nothing special." The lack of enthusiasm or strong emotion in the statement conveys a sense of indifference or
#
# Text: What a wonderful day! I feel so happy.
# ...
